# %%
import numpy as np
import pandas as pd
from preprocess import filter_pos, process_text, remove_nt
from vader import get_sentiment
from pain_points import get_frequent, get_negative_tokens, create_token_match_columns, process_token_df

# %%
import os
from pymongo import MongoClient
from pycommon.warehouse.load_queries import acquire_all_review_data
import datetime

# %%
#port = os.getenv("MONGO_PORT") if os.getenv("MONGO_PORT") is not None else 27017 # MONGO_PORT defines the port number. 
port= 27017
mongo_client = MongoClient('localhost', port) # mongo is always the host. Again, docker handles this dns resolution.

# And we're good! mongo is ready to be used. Most of the methods in pycommon/warehouse need you to 
# pass in the mongoclient. 

reviews = acquire_all_review_data(
        mongo_client, 
        datetime.datetime(2001,12,1,0,0).timestamp(), # from
        datetime.datetime(2018,12,1,0,0).timestamp(), # to
        "SimpangAsia",
        "Yelp"
    )

reviews_array = []
for review in reviews:
    reviews_array.append(review)
# Out:
# acquire all review data with skip and limit types: <class 'NoneType'> <class 'NoneType'>

# %%
len(reviews_array)
# Out:
# 1275

# %%
d = {
    "timestamp": [reviews_array[i].timestamp for i in range(0,len(reviews_array))],
    "source_id": [reviews_array[i].source_id for i in range(0,len(reviews_array))],
    "review_id": [reviews_array[i].review_id for i in range(0,len(reviews_array))],
    "business_id": [reviews_array[i].business_id for i in range(0,len(reviews_array))],
    "review_content": [reviews_array[i].content for i in range(0,len(reviews_array))],
    "review_rating": [reviews_array[i].rating for i in range(0,len(reviews_array))],
}

df = pd.DataFrame(data=d)

# %%
df.head()
# Out:
#    timestamp source_id                             review_id  business_id  \
# 0 2018-11-26      Yelp  b654548d-4783-4013-b247-ff5b5a833e8f  SimpangAsia
# 1 2018-10-25      Yelp  4b385f99-0613-441f-9b7a-eeb996074c77  SimpangAsia
# 2 2018-11-14      Yelp  35957733-3885-4542-894a-bc506111fdf7  SimpangAsia
# 3 2018-11-02      Yelp  eeab5b21-2ab0-4819-a101-f11c2c15cb28  SimpangAsia
# 4 2018-09-16      Yelp  49b15113-6d94-4de5-a790-8e076ed7e6a4  SimpangAsia
#
#                                       review_content  review_rating
# 0  Sat 10:30a, no wait for 5, parking lot w valet...              5
# 1  I've heard a lot of good things about Simpang ...              5
# 2  Great and simple restaurant in West LA. The am...              4
# 3  Indonesia goodness! The fish was extremely cri...              4
# 4  Not many Indonesian restaurants near where we ...              4

# %%
# retains only adjectives and adverbs for reviews
df['review_tokens'] = df['review_content'].apply(filter_pos)
# Makes lowercase, removes punctuation and stopwords, and lemmatizes remaining words
df['review_tokens'] = df['review_tokens'].apply(process_text)
# removes the word 'nt'
df['review_tokens'] = df['review_tokens'].apply(remove_nt)

# %%
df.head()
# Out:
#    timestamp source_id                             review_id  business_id  \
# 0 2018-11-26      Yelp  b654548d-4783-4013-b247-ff5b5a833e8f  SimpangAsia
# 1 2018-10-25      Yelp  4b385f99-0613-441f-9b7a-eeb996074c77  SimpangAsia
# 2 2018-11-14      Yelp  35957733-3885-4542-894a-bc506111fdf7  SimpangAsia
# 3 2018-11-02      Yelp  eeab5b21-2ab0-4819-a101-f11c2c15cb28  SimpangAsia
# 4 2018-09-16      Yelp  49b15113-6d94-4de5-a790-8e076ed7e6a4  SimpangAsia
#
#                                       review_content  review_rating  \
# 0  Sat 10:30a, no wait for 5, parking lot w valet...              5
# 1  I've heard a lot of good things about Simpang ...              5
# 2  Great and simple restaurant in West LA. The am...              4
# 3  Indonesia goodness! The fish was extremely cri...              4
# 4  Not many Indonesian restaurants near where we ...              4
#
#                                        review_tokens
# 0  thorough incorrect real garlic bagu deliciou a...
# 1  thorough long crazy complimentary absolute fla...
# 2  great simple slow nice great flavorful Green_P...
# 3  high crispy great considerable also dice Green...
# 4  many Indonesia sure west dry embarrassedly pop...

# %%
# getting tokens
most_freq = get_frequent(df['review_tokens'],500)
neg_corp = get_negative_tokens(most_freq)
len(neg_corp)
# Out:
# 33

# %%
create_token_match_columns(neg_corp, df)

# %%
df.head()
# Out:
#    timestamp source_id                             review_id  business_id  \
# 0 2018-11-26      Yelp  b654548d-4783-4013-b247-ff5b5a833e8f  SimpangAsia
# 1 2018-10-25      Yelp  4b385f99-0613-441f-9b7a-eeb996074c77  SimpangAsia
# 2 2018-11-14      Yelp  35957733-3885-4542-894a-bc506111fdf7  SimpangAsia
# 3 2018-11-02      Yelp  eeab5b21-2ab0-4819-a101-f11c2c15cb28  SimpangAsia
# 4 2018-09-16      Yelp  49b15113-6d94-4de5-a790-8e076ed7e6a4  SimpangAsia
#
#                                       review_content  review_rating  \
# 0  Sat 10:30a, no wait for 5, parking lot w valet...              5
# 1  I've heard a lot of good things about Simpang ...              5
# 2  Great and simple restaurant in West LA. The am...              4
# 3  Indonesia goodness! The fish was extremely cri...              4
# 4  Not many Indonesian restaurants near where we ...              4
#
#                                        review_tokens    bad   hard  \
# 0  thorough incorrect real garlic bagu deliciou a...  False  False
# 1  thorough long crazy complimentary absolute fla...  False  False
# 2  great simple slow nice great flavorful Green_P...  False  False
# 3  high crispy great considerable also dice Green...  False  False
# 4  many Indonesia sure west dry embarrassedly pop...  False  False
#
#    disappoint  ...    sorry  annoy  worse  negative   hide  disgust   sick  \
# 0       False  ...    False  False  False     False  False    False  False
# 1       False  ...    False  False  False     False  False    False  False
# 2       False  ...    False  False  False     False  False    False  False
# 3       False  ...    False  False  False     False  False    False  False
# 4       False  ...    False  False  False     False  False    False  False
#
#    hesitant  nasty   weak
# 0     False  False  False
# 1     False  False  False
# 2     False  False  False
# 3     False  False  False
# 4     False  False  False
#
# [5 rows x 40 columns]

# %%
token_df = process_token_df(neg_corp, df)
# Out:
# C:\Users\iechi\Desktop\Files\Work\Coding Projects\BBB\src\nlp\pain_points.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   token_df['neg_sentence'] = token_df['review_content'].apply(lambda x: get_neg_sentence(neg_token_list[index], x))
# C:\Users\iechi\Desktop\Files\Work\Coding Projects\BBB\src\nlp\pain_points.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   token_df.dropna(inplace=True)
# C:\Users\iechi\Desktop\Files\Work\Coding Projects\BBB\src\nlp\pain_points.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   token_df['df_len'] = len(token_df)
# C:\Users\iechi\Desktop\Files\Work\Coding Projects\BBB\src\nlp\pain_points.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   token_df['token'] = neg_token_list[index]

# %%
token_df.sort_values(['df_len','token'], ascending = False, inplace=True)
token_df.reset_index(inplace=True)

# %%
# getting the top 10 tokens
# NOT USED
top_ten = token_df['token'].unique()[:10]
top_ten
top_eleven = token_df['token'].unique()[:11]
top_eleven
# Out:
# array(['bad', 'hard', 'disappoint', 'unfortunate', 'difficult',
#        'terrible', 'weird', 'serious', 'poor', 'worst', 'tough'],
#       dtype=object)

# %%
# getting the index number for the top 10 tokens up till the last evidence (neg_sentence)
# NOT USED
index = token_df[token_df['token'] == top_eleven[-1]].index.values[0]
index
# Out:
# 215

# %%
# seeing the top 10 negative tokens and their evidences
# NOT USED
token_df[:index]
# Out:
#      level_0  index  timestamp source_id  \
# 0          0      9 2018-08-06      Yelp
# 1          1     51 2017-10-01      Yelp
# 2          2     66 2017-12-07      Yelp
# 3          3     69 2018-11-07      Yelp
# 4          4    205 2016-06-11      Yelp
# 5          5    235 2018-03-06      Yelp
# 6          6    252 2018-04-08      Yelp
# 7          7    280 2018-06-16      Yelp
# 8          8    338 2014-07-22      Yelp
# 9          9    339 2016-10-21      Yelp
# 10        10    343 2017-06-04      Yelp
# 11        11    361 2018-03-06      Yelp
# 12        12    392 2017-08-20      Yelp
# 13        13    439 2017-04-27      Yelp
# 14        14    483 2015-09-13      Yelp
# 15        15    498 2013-06-16      Yelp
# 16        16    534 2016-10-21      Yelp
# 17        17    535 2015-06-27      Yelp
# 18        18    540 2013-03-27      Yelp
# 19        19    576 2017-08-20      Yelp
# 20        20    590 2012-10-25      Yelp
# 21        21    696 2013-08-24      Yelp
# 22        22    730 2012-11-09      Yelp
# 23        23    731 2012-12-01      Yelp
# 24        24    798 2013-04-03      Yelp
# 25        25    803 2014-06-02      Yelp
# 26        26    804 2010-07-04      Yelp
# 27        27    826 2013-01-28      Yelp
# 28        28    832 2012-11-08      Yelp
# 29        29    851 2015-12-25      Yelp
# ..       ...    ...        ...       ...
# 185      115    308 2017-01-12      Yelp
# 186      116    445 2015-03-06      Yelp
# 187      117    490 2014-01-09      Yelp
# 188      118    522 2015-06-20      Yelp
# 189      119    959 2011-04-07      Yelp
# 190      120   1147 2009-02-22      Yelp
# 191      121   1202 2010-11-13      Yelp
# 192      122   1222 2009-11-10      Yelp
# 193      199    205 2016-06-11      Yelp
# 194      200    229 2016-05-13      Yelp
# 195      201    403 2017-02-27      Yelp
# 196      202    491 2017-03-08      Yelp
# 197      203    674 2011-11-30      Yelp
# 198      204    737 2014-07-04      Yelp
# 199      205    919 2010-12-15      Yelp
# 200      206    956 2013-12-10      Yelp
# 201      207    986 2010-02-08      Yelp
# 202      208    993 2010-01-13      Yelp
# 203      209   1108 2008-10-24      Yelp
# 204      210   1188 2013-01-03      Yelp
# 205      268     69 2018-11-07      Yelp
# 206      269    133 2017-03-13      Yelp
# 207      270    315 2014-07-18      Yelp
# 208      271    439 2017-04-27      Yelp
# 209      272    659 2016-04-24      Yelp
# 210      273    846 2011-09-07      Yelp
# 211      274    873 2013-07-13      Yelp
# 212      275    934 2009-09-01      Yelp
# 213      276   1074 2012-06-03      Yelp
# 214      277   1187 2009-11-13      Yelp
#
#                                 review_id  business_id  \
# 0    3b3854d0-957e-4f01-8ae8-98dfca70d307  SimpangAsia
# 1    17e90eec-b87e-466a-9a9d-cef9c1fb89e2  SimpangAsia
# 2    09748bb3-2e5e-4485-8b29-f756557fa222  SimpangAsia
# 3    71f4192f-65c9-4927-bb56-f77c153700bd  SimpangAsia
# 4    f8b5e6c3-20e8-4b33-a91d-4e0b8075a82b  SimpangAsia
# 5    41af5769-bc4f-4ea0-a1f8-feaec25b458e  SimpangAsia
# 6    72e42ccc-0efd-44f8-a068-218bec430c60  SimpangAsia
# 7    c654fd5e-7f52-4b9f-8784-2fd68d67ded8  SimpangAsia
# 8    3d9d0d16-b534-4baa-ae23-9635cfe83475  SimpangAsia
# 9    4d27c7bb-8dde-4e5f-82e0-9866ca1cb165  SimpangAsia
# 10   8886d67f-b4ee-44a2-ba9e-c1f81927dd8d  SimpangAsia
# 11   9f88120b-f725-4767-bcc2-c630007b914f  SimpangAsia
# 12   e427afdf-26c5-4224-8233-03883e726314  SimpangAsia
# 13   d61b88c3-97b3-4502-b64c-b29f95b276bb  SimpangAsia
# 14   b631163a-3215-452e-80b9-1d08082d6b16  SimpangAsia
# 15   9c2aabfc-44ff-4cbb-b0db-e8c3f0ecc26b  SimpangAsia
# 16   97225d26-5a74-47d3-afef-a26e7e80770d  SimpangAsia
# 17   57f3b99f-305b-4f04-a37f-4fdc39579536  SimpangAsia
# 18   e1b9fa28-8df2-4b83-b9fd-2e5c8a978453  SimpangAsia
# 19   9f88002d-fd15-43f1-8ff2-2912ecc09ff6  SimpangAsia
# 20   4c019393-3f26-48b3-a105-b665be991f86  SimpangAsia
# 21   37bcd71e-060e-4869-b2aa-4dfd6baa3861  SimpangAsia
# 22   6503dce1-45ad-4eee-b790-b26ca4c4a8a9  SimpangAsia
# 23   e624bb8b-9e92-4ffb-9c20-695d605ea830  SimpangAsia
# 24   94f36b52-2a26-4b08-a09f-a03a7b1bcee5  SimpangAsia
# 25   f5f270c5-90c5-49da-993f-cbdb797f5c74  SimpangAsia
# 26   5f291766-b551-4974-9cde-2db0fb9cce7e  SimpangAsia
# 27   800ac2b2-a2b8-45fe-af6e-09a34d5a0e00  SimpangAsia
# 28   542fe551-838b-4e85-9b9a-c8293b00effa  SimpangAsia
# 29   1533d07b-0ecc-4975-909e-1e55eb74d270  SimpangAsia
# ..                                    ...          ...
# 185  1a9b53ad-559a-4ecb-9863-bb902d6353f5  SimpangAsia
# 186  0739a2d6-0e7f-4a36-8c25-291c4e78efdb  SimpangAsia
# 187  90ebb02b-6ac1-42ee-94a9-c45a84dbbefa  SimpangAsia
# 188  43b64624-8080-4504-840a-18fbcfc39249  SimpangAsia
# 189  785bd14e-4253-4900-934e-d53e4f27d713  SimpangAsia
# 190  7f1a679a-86bb-40d3-945b-84ddc685de87  SimpangAsia
# 191  cc87917e-5097-4177-81b6-7d4557df5d33  SimpangAsia
# 192  86b4f527-3199-4c7d-9031-8d30c3793c49  SimpangAsia
# 193  f8b5e6c3-20e8-4b33-a91d-4e0b8075a82b  SimpangAsia
# 194  fff15dfa-4a6c-4904-9a98-bceb63868c27  SimpangAsia
# 195  04b67012-f4fd-4990-b3d5-55fb6bb98090  SimpangAsia
# 196  235d6bad-f7df-433b-9883-2c2473cefbb6  SimpangAsia
# 197  61b5b029-a032-47f6-bc87-a59af275ee13  SimpangAsia
# 198  816a90b3-022c-44e5-934e-3169cf2c4e7b  SimpangAsia
# 199  76e35599-9640-40de-acba-da265ecc3fa0  SimpangAsia
# 200  4d3cdf68-e915-4cec-902e-fbcb42823b5a  SimpangAsia
# 201  0503f171-7337-42dd-9911-eaeb53ad174d  SimpangAsia
# 202  30243de9-7de4-4328-a7c0-74df03a93866  SimpangAsia
# 203  849d739c-b8d6-4cab-87e3-73db201bae26  SimpangAsia
# 204  cc6c1388-b606-489b-bab6-8a4831c1d522  SimpangAsia
# 205  71f4192f-65c9-4927-bb56-f77c153700bd  SimpangAsia
# 206  c230bc92-9209-406a-a113-5b1e966ea38b  SimpangAsia
# 207  228eebee-9901-4048-8a70-02801172b6aa  SimpangAsia
# 208  d61b88c3-97b3-4502-b64c-b29f95b276bb  SimpangAsia
# 209  b12fa3a9-9624-46ba-b578-627c167b7c48  SimpangAsia
# 210  ac9f097e-0c90-4c8e-81ee-43ccad9eb15d  SimpangAsia
# 211  aa291b1b-19db-4c38-aaf4-b2a9a00266a0  SimpangAsia
# 212  98c62b69-6e47-4886-a45c-65270e43bfd9  SimpangAsia
# 213  3cca00c6-7cb5-4181-8c6b-84bb87f3314c  SimpangAsia
# 214  d355d310-e45e-447c-9ce0-962236cc8885  SimpangAsia
#
#                                         review_content  review_rating  \
# 0    OMG! First time in this place after searching ...              5
# 1    Simpang was my favorite discovery when I moved...              5
# 2    Simpang Asia serves some great dishes. The goo...              4
# 3    Worst place ever.. very bad services and food ...              1
# 4    The service was absolutely horrible.  I'm sure...              1
# 5    Food is good with good price, very like tai fo...              4
# 6    If you know anything about my Yelp reviews - m...              5
# 7    Ordered from yelp . After 1 hour when I left t...              1
# 8    If you want to sample what Indonesian food tas...              4
# 9    Bad service, horrible operations, period.We go...              1
# 10   Roti Paratha: Incredible flaky texture of flat...              5
# 11   they did lots of changes to this place. some g...              3
# 12   So I order Two Nasi bungkus from postmates and...              1
# 13   Worst experience ever! I have limited time in ...              1
# 14   This was my first time experiencing Indonesian...              5
# 15   Where do I start ... Wow. There, that works.Th...              4
# 16   I was very disappointed with this place after ...              2
# 17   Good food but bad service. The waiter brings o...              3
# 18   This is heaven for me who came from Indonesia ...              5
# 19   OMG, where should I start. So My friend order ...              1
# 20   3.5 stars. It's prettty good, but some things ...              3
# 21   I can't believe I've never reviewed this place...              5
# 22   This is my very first 3 1/2 star review becaus...              3
# 23   NOWAY. If you want diarrhea .... and if you ar...              1
# 24   Big fans of everything about Simpang except fo...              4
# 25   OK, so I was in LA  for some business and I wa...              5
# 26   Probably closer to 4.5 stars, but still one of...              4
# 27   So I've never had Indo food before, but I'm ve...              4
# 28   Where else can you get home-y Indonesian food?...              4
# 29   Decided to try this place on a whim, as its ne...              4
# ..                                                 ...            ...
# 185  Lo, I am saved!!! Delicious, authentic Indones...              5
# 186  Good food, but service was slow. I've had Indo...              3
# 187  I used to like this restaurant. The food isn't...              3
# 188  We have lived up the street from this place fo...              5
# 189  I like this place.Was here the other night w/ ...              4
# 190  Gorgeous! this place was described as one of t...              4
# 191  our go-to place whenever we crave for decent i...              4
# 192  whoa whoa whoa...where have you BEEN all my li...              4
# 193  The service was absolutely horrible.  I'm sure...              1
# 194  I'm going to start off by saying this would ha...              2
# 195  Not exactly sure who is eating here and review...              1
# 196  This review is for the Management especially t...              1
# 197  I'm not Indonesian.  I've never had Indonesian...              4
# 198  First time there and unfortunately that will b...              2
# 199  This place has always been one of my favorite ...              3
# 200  Come here for the food! The Laksa here is as g...              4
# 201  1. When someone ask you how you want the egg's...              1
# 202  On Saturday, I checked out Simpang Asia with J...              3
# 203  We live in the neighborhood and I stock up on ...              2
# 204  The vegetarian nasi bungkus is mediocre, it wa...              3
# 205  Worst place ever.. very bad services and food ...              1
# 206  Another hit and miss culinary adventure but mo...              2
# 207  Not my dish, unfortunately.Very cheap price, c...              3
# 208  Worst experience ever! I have limited time in ...              1
# 209  I truly like the idea of taking cuisine and pu...              1
# 210  I'm a regular customer at Simpang Asia. Althou...              3
# 211  First time here. Saturday July 12. around 7:30...              1
# 212  Tasty Indonesian food! yummms =pBut it's small...              3
# 213  some good and some bad mixed all together.trie...              3
# 214  DID  NOT  LIKE  THE  FOOD  . .We went there, t...              2
#
#                                          review_tokens    bad   ...     \
# 0    first everlasting Indonesia Malaysia happy yum...   True   ...
# 1    favorite first new subsequent locality bad eas...   True   ...
# 2    great thorough tender bad fast hot enough odd ...   True   ...
# 3    worst ever bad thorough mild extra hot true le...   True   ...
# 4    absolute horrible sure easier bland reasonable...   True   ...
# 5               thorough thorough bad eventual earlier   True   ...
# 6    primary bad legit favorite ruen flavorful auth...   True   ...
# 7                                           hungry bad   True   ...
# 8    Indonesia proper Indonesia Indonesia considera...   True   ...
# 9    bad horrible waitres many sure subsequent subs...   True   ...
# 10   incredible flake light beautiful much consider...   True   ...
# 11   bad nasi somay nasi literal bad nasi spicy any...   True   ...
# 12   usual ridiculou rendang mere im extra nasi sma...   True   ...
# 13   worst ever never still slow even absolute insa...   True   ...
# 14   first Indonesia never bad sticky shred flake c...   True   ...
# 15   almost first incredible thorough incredible ba...   True   ...
# 16   disappoint far first free second almost away t...   True   ...
# 17   thorough bad chili extra also ready alway actu...   True   ...
# 18   real authentic Indonesia Indonesia considerabl...   True   ...
# 19   excite Indonesia first small heavy kind whatev...   True   ...
# 20   prettty thorough thorough amaze flake le oily ...   True   ...
# 21   never first Indonesia warung loose casual typi...   True   ...
# 22   first many probable preliminary thorough whole...   True   ...
# 23          nasty nasty nasty also bad sure maybe even   True   ...
# 24   boastful first bad reasonable prompt illegal t...   True   ...
# 25   ethnic Indonesia Indonesia quite Indonesia imm...   True   ...
# 26   probable closer still considerable Indonesia e...   True   ...
# 27   never happy different true thorough sweet actu...   True   ...
# 28   else home Indonesia reasonable thorough reason...   True   ...
# 29   near excellent Indonesia similar quite Thai bo...   True   ...
# ..                                                 ...    ...   ...
# 185  authentic Indonesia serious stoke low glad eve...  False   ...
# 186  thorough slow Indonesia familiar little hard e...  False   ...
# 187  bad true quite oily dense quite vibrant tasty ...   True   ...
# 188  never never ever Indonesia soooooooooo thoroug...  False   ...
# 189  familiar thorough little thick least tasty sev...  False   ...
# 190  gorgeou last place considerable still nasi gre...  False   ...
# 191  whenever proper Indonesia reasonable nasi rend...  False   ...
# 192  Indonesia damn thorough first ago thorough rea...  False   ...
# 193  absolute horrible sure easier bland reasonable...   True   ...
# 194  slender shock spicy promise honest overall pro...  False   ...
# 195  precise sure poor real slimy cold cold serious...  False   ...
# 196  particular clear piss rude available empty fir...  False   ...
# 197  Indonesia never Indonesia alway probable reaso...  False   ...
# 198  first unfortunate last major even away real po...  False   ...
# 199  alway favorite almost recent unsurethi Indones...  False   ...
# 200  thorough smaller reasonable thorough skimpy la...  False   ...
# 201  fair scarce acceptable considerable thorough I...   True   ...
# 202  tiny almost dine alternative smaller several v...   True   ...
# 203  wanna double prepare ardent hot proper cheap a...  False   ...
# 204  vegetarian mediocre flavorful whole thorough m...  False   ...
# 205  worst ever bad thorough mild extra hot true le...   True   ...
# 206  cuisine hence prepackage old thorough sure sma...  False   ...
# 207  unfortunate cheap fair nice south Asia vegetar...  False   ...
# 208  worst ever never still slow even absolute insa...   True   ...
# 209  true new modern traditional perhap western ren...  False   ...
# 210  regular sure vice versa general rather inconsi...  False   ...
# 211  first nice awhile eventual main nasi nasi also...  False   ...
# 212  tasty Indonesia small long sure decided first ...  False   ...
# 213  thorough bad mix togethertry traditional thoro...   True   ...
# 214  Asia worst Indonesia rude even nice happy popu...  False   ...
#
#      negative   hide  disgust   sick  hesitant  nasty   weak  \
# 0       False  False    False  False     False  False  False
# 1       False  False    False  False     False  False  False
# 2       False  False    False  False     False  False  False
# 3       False  False    False  False     False  False  False
# 4       False  False    False   True     False  False  False
# 5       False  False    False  False     False  False  False
# 6       False  False    False  False     False  False  False
# 7       False  False    False  False     False  False  False
# 8       False  False    False  False     False  False  False
# 9       False  False    False  False     False  False  False
# 10      False  False    False  False     False  False  False
# 11      False  False    False  False     False  False  False
# 12      False  False    False  False     False  False  False
# 13      False  False    False  False     False  False  False
# 14      False  False    False  False     False  False  False
# 15      False  False    False  False     False  False  False
# 16      False  False    False  False     False  False  False
# 17      False  False    False  False     False  False  False
# 18      False  False    False  False     False  False  False
# 19      False  False    False  False     False  False  False
# 20      False  False    False  False     False  False  False
# 21      False  False    False  False     False  False  False
# 22      False  False    False  False     False  False  False
# 23      False  False    False  False     False   True  False
# 24      False  False    False  False     False  False  False
# 25      False  False    False  False     False  False  False
# 26      False  False    False  False     False  False  False
# 27      False  False    False  False     False  False  False
# 28      False  False    False  False     False  False  False
# 29      False  False    False  False     False  False  False
# ..        ...    ...      ...    ...       ...    ...    ...
# 185     False  False     True  False     False  False  False
# 186     False  False    False  False     False  False  False
# 187     False  False    False  False     False  False  False
# 188     False  False    False  False     False  False  False
# 189     False  False    False  False     False  False  False
# 190     False  False    False  False     False  False  False
# 191     False  False    False  False     False  False  False
# 192     False  False    False  False     False  False  False
# 193     False  False    False   True     False  False  False
# 194     False  False    False  False     False  False  False
# 195     False  False    False  False     False  False  False
# 196     False  False    False  False     False  False  False
# 197     False  False    False  False     False  False  False
# 198     False  False    False  False     False  False  False
# 199     False  False    False  False     False  False  False
# 200     False  False    False  False     False  False  False
# 201      True  False    False  False     False  False  False
# 202     False  False    False  False     False  False  False
# 203     False  False    False  False     False  False  False
# 204     False  False    False  False     False  False  False
# 205     False  False    False  False     False  False  False
# 206     False  False    False  False     False  False  False
# 207     False  False    False  False     False  False  False
# 208     False  False    False  False     False  False  False
# 209     False  False    False  False     False  False  False
# 210     False  False    False  False     False  False  False
# 211     False  False    False  False     False  False  False
# 212     False  False    False  False     False  False  False
# 213     False  False    False  False     False  False  False
# 214     False  False    False  False     False  False  False
#
#                                           neg_sentence  df_len    token
# 0     It's insanely spicy! I felt the fire in my mo...      48      bad
# 1                    Let's start with the bad: parking      48      bad
# 2     The bad side is that some dishes came out ver...      48      bad
# 3               very bad services and food is not good      48      bad
# 4     It was so bad, he filed a report with the LA ...      48      bad
# 5     Too bad I finally have this after I lived in ...      48      bad
# 6    If you know anything about my Yelp reviews - m...      48      bad
# 7                Kids are so hungry and Grubhub so bad      48      bad
# 8                                Their Es Teler is bad      48      bad
# 9             Bad service, horrible operations, period      48      bad
# 10    It's been highly raved about on Yelp and I fa...      48      bad
# 11    one of those bad changes, we cant order nasi ...      48      bad
# 12    OMG, three hours later it gives me a really b...      48      bad
# 13                        Way too slow and bad service      48      bad
# 14                                           Bad Asian      48      bad
# 15   There is something to be said when I almost dr...      48      bad
# 16    Fourth, the food are awful; I got date Padang...      48      bad
# 17                           Good food but bad service      48      bad
# 18    It's too bad they don't have another branch i...      48      bad
# 19    I mean all I can say is I have a really bad f...      48      bad
# 20   The bad: I found a strand of hair in my soup, ...      48      bad
# 21    The tempeh was okay, not bad, but definitely ...      48      bad
# 22    He was doing multiple jobs and I kind of felt...      48      bad
# 23      My stomach was hurting so bad after their food      48      bad
# 24   First the bad: The lot tends to fill up pretty...      48      bad
# 25                          Too bad I live so far away      48      bad
# 26         Too bad there are no Indo food in San Diego      48      bad
# 27     some countries have outlawed durian in publi...      48      bad
# 28                                 I'd be bad for sure      48      bad
# 29    Its like Thai food is the beta test for Indon...      48      bad
# ..                                                 ...     ...      ...
# 185       Seriously guys, I am so stoked on this place      13  serious
# 186   It was seriously only one small pancake sized...      13  serious
# 187   Do they have a new cook?Lastly, this restaura...      13  serious
# 188                           Seriously out of control      13  serious
# 189                                          Seriously      13  serious
# 190                  seriously, get some pocky instead      13  serious
# 191                                      no, seriously      13  serious
# 192                                   i mean seriously      13  serious
# 193  The most important piece of information - both...      12     poor
# 194   The poor valet, ran up to them and asked them...      12     poor
# 195  Not exactly sure who is eating here and review...      12     poor
# 196   Are you serious? Who hire the parking company...      12     poor
# 197    I would have given it 5 stars save for the i...      12     poor
# 198    Basically, you pay for what you ordered whet...      12     poor
# 199  The reason I am giving this place a 3 star and...      12     poor
# 200  Come here for the food! The Laksa here is as g...      12     poor
# 201   But because of the poor service and the bad e...      12     poor
# 202  ikan asin- I liked this this but compared to a...      12     poor
# 203   It's possible we simply chose poorly (I think...      12     poor
# 204    Next time, ill try the laksa, looks like it ...      12     poor
# 205                                   Worst place ever      10    worst
# 206   Pass These:Roti pratha - Good but surely the ...      10    worst
# 207  The worst thing about Asian food is that they ...      10    worst
# 208  Worst experience ever! I have limited time in ...      10    worst
# 209    The worst part of the meal was that it came ...      10    worst
# 210        **Pempek - possibly the worst I've ever had      10    worst
# 211   The worst experience I ever had eating at an ...      10    worst
# 212  I also had the worst iced ginger coffee in my ...      10    worst
# 213                    the worst drink i have ever had      10    worst
# 214  ], but when we've eaten there, we had the wors...      10    worst
#
# [215 rows x 45 columns]

# %%
# from pycommon.warehouse.store_insights import store_painpoint_insights
# from pycommon.warehouse.objects import painpoint_object

# TODO: convert all the stuff above to a list of painpoint_object classes. Each list is one painpoint.

# NOTE: ching I changed it. Pls follow the format below:
# class painpoint_object:
#    def __init__ (self, title: str, description: str, solution: str, source_id: str, business_id: str, example_review_ids: List[str], timestamp: int):

# e.g. a painpoint object for the 'bad' reviews

# %%
evid= {}

evid[1094] = 'A'

# %%
evid
# Out:
# {1094: 'A'}

# %%
review_id_evidence = {}
review_ids = token_df[token_df['token'] == 'bad']['review_id']
for review_id in review_ids:

    evidence = list(token_df[(token_df['review_id'] == review_id) & (token_df['token'] == 'bad')]['neg_sentence'])
    review_id_evidence[review_id] = evidence

# %%
review_id_evidence
# Out:
# {'3b3854d0-957e-4f01-8ae8-98dfca70d307': [" It's insanely spicy! I felt the fire in my mouth till the next day that's how bad it was!!! But now I m ow for next time! Can't wait go back!!!"],
#  '17e90eec-b87e-466a-9a9d-cef9c1fb89e2': ["Let's start with the bad: parking"],
#  '09748bb3-2e5e-4485-8b29-f756557fa222': [' The bad side is that some dishes came out very fast and were not hot enough'],
#  '71f4192f-65c9-4927-bb56-f77c153700bd': [' very bad services and food is not good'],
#  'f8b5e6c3-20e8-4b33-a91d-4e0b8075a82b': [' It was so bad, he filed a report with the LA Department of Public Health'],
#  '41af5769-bc4f-4ea0-a1f8-feaec25b458e': [' Too bad I finally have this after I lived in culver for three years, I should try it earlier'],
#  '72e42ccc-0efd-44f8-a068-218bec430c60': ['If you know anything about my Yelp reviews - my primary goal for being on this site is to read all the bad reviews and respond to them in my review to assure you that this place is legit'],
#  'c654fd5e-7f52-4b9f-8784-2fd68d67ded8': [' Kids are so hungry and Grubhub so bad'],
#  '3d9d0d16-b534-4baa-ae23-9635cfe83475': ['Their Es Teler is bad'],
#  '4d27c7bb-8dde-4e5f-82e0-9866ca1cb165': ['Bad service, horrible operations, period'],
#  '8886d67f-b4ee-44a2-ba9e-c1f81927dd8d': [" It's been highly raved about on Yelp and I failed to take into consideration the fact that this dish's admirers may have a bad case of BASIC"],
#  '9f88120b-f725-4767-bcc2-c630007b914f': [' one of those bad changes, we cant order nasi goreng jawa in not spicy anymore'],
#  'e427afdf-26c5-4224-8233-03883e726314': [' OMG, three hours later it gives me a really bad diarrhea'],
#  'd61b88c3-97b3-4502-b64c-b29f95b276bb': [' Way too slow and bad service'],
#  'b631163a-3215-452e-80b9-1d08082d6b16': [' Bad Asian'],
#  '9c2aabfc-44ff-4cbb-b0db-e8c3f0ecc26b': ["There is something to be said when I almost drop my fork and spoon after I take a first bite: It's either incredibly good or incredibly bad"],
#  '97225d26-5a74-47d3-afef-a26e7e80770d': [' Fourth, the food are awful; I got date Padang, siomai Bandung and nasi goreng; there were bad after taste or flavor on the food; totally not an original Indonesian food'],
#  '57f3b99f-305b-4f04-a37f-4fdc39579536': ['Good food but bad service'],
#  'e1b9fa28-8df2-4b83-b9fd-2e5c8a978453': [" It's too bad they don't have another branch in San Diego"],
#  '9f88002d-fd15-43f1-8ff2-2912ecc09ff6': [' I mean all I can say is I have a really bad first time experience with this place'],
#  '4c019393-3f26-48b3-a105-b665be991f86': ["The bad: I found a strand of hair in my soup, which kind of made me lose my appetite because I don't know what else might be lurking in there"],
#  '37bcd71e-060e-4869-b2aa-4dfd6baa3861': [' The tempeh was okay, not bad, but definitely not the best'],
#  '6503dce1-45ad-4eee-b790-b26ca4c4a8a9': [' He was doing multiple jobs and I kind of felt bad for him'],
#  'e624bb8b-9e92-4ffb-9c20-695d605ea830': [' My stomach was hurting so bad after their food'],
#  '94f36b52-2a26-4b08-a09f-a03a7b1bcee5': ['First the bad: The lot tends to fill up pretty quick and some drivers may decide to just block you in to get their Simpang fix'],
#  'f5f270c5-90c5-49da-993f-cbdb797f5c74': [' Too bad I live so far away'],
#  '5f291766-b551-4974-9cde-2db0fb9cce7e': [' Too bad there are no Indo food in San Diego'],
#  '800ac2b2-a2b8-45fe-af6e-09a34d5a0e00': [' \xa0some countries have outlawed durian in public places and even in hotels, bc the smell is so bad'],
#  '542fe551-838b-4e85-9b9a-c8293b00effa': ["I'd be bad for sure"],
#  '1533d07b-0ecc-4975-909e-1e55eb74d270': [' Its like Thai food is the beta test for Indonesian food(or maybe its a bad \xa0copy?)'],
#  'f38a85a2-875f-4faa-a851-cc0315c79445': [' I used to hate it back when Indo Cafe was still open and based on one bad experience with their Ketoprak peanut sauce (it was not fresh and too Americanized peanut butter feel)'],
#  '7080c7ce-e6e2-4400-8d11-62a443910979': ['The only bad thing about this place is parking (*cringes*)'],
#  '00ccbff3-4c05-4365-9ede-c970a7d209a0': [' \xa0Too bad I live 3,000 miles east'],
#  'c5453e55-5984-4fce-afa6-81f89fb198e1': [' \xa0The Laksa was also pretty bad'],
#  'a09b0689-bf41-447e-8e78-6ff94d26abad': ['This is not to say they are a bad restaurant, everybody has a bad night but I will not be ordering from them again'],
#  '1a919e05-4664-4a51-9e5a-b405a15cece2': [' \xa0I came here a second time and had a very bad experience'],
#  '0503f171-7337-42dd-9911-eaeb53ad174d': [' But because of the poor service and the bad experience, I wish Yelp had put a 0 or negative remark'],
#  '7c7124fa-7f72-4853-b74f-7d46f9414733': [" \xa0Yeah, it's that bad"],
#  '9a4d2f0f-aee2-4fa8-b5c0-afe82c61debb': ['My only complaint is the parking is a bit bad in this area'],
#  '98e5ac1e-f14c-4565-8270-dd9a0710297b': [' \xa0Not bad, but not impressive'],
#  '3e4e6aeb-76d1-4de2-9c1b-b354e4265741': [' \xa0small complex parking and vicinity parking is bad'],
#  '704f1428-72d5-40a1-97e0-01a93ea64f45': ["' Bad business practices"],
#  '20854aa8-5e18-467e-a2c6-6482b7e1fa7f': [' (I dont know about you fellow yelpers but if I walk into a place and it smells even slightly fishy or bad im out of there) We grabbed a couple of menus and sat down at a small little table'],
#  '3cca00c6-7cb5-4181-8c6b-84bb87f3314c': ['some good and some bad mixed all together'],
#  '9d76db23-b291-42f8-a262-e98ff1ff0da1': [" \xa0Food is good but service is bad, there's not parking, bad ambience"],
#  '7f9a9343-d4ab-4a81-8c4d-47fa59379448': [' Two of the dishes were so bad that we threw them out and my boyfriend insisted that there was meat in one of them(They were all supposed to be vegetarian)'],
#  'a5098529-f1c5-4064-afc1-b34c801416ef': [' Too bad it is so far from the South Bay or we would eat there 2 or 3 times a week for sure'],
#  'c7c5a93a-186f-4c1c-8c3e-99f5e827dc96': [' (The only bad thing about here is that the parking situation can be bad at times)The Indonesian food at the cafe is cheap and very good too! (Better than Indo Cafe across the street)']}

# %%
# final_tokens = list(pd.unique(token_df['token']))
# for token in final_tokens:
    
#     review_id_evidence = {}
    
#     review_ids = token_df[token_df['token'] == token]['review_id']
#     for review_id in review_ids:

#         evidence = list(token_df[(token_df['review_id'] == review_id) & (token_df['token'] == token)]['neg_sentence'])
#         review_id_evidence[review_id] = [evidence]

# %%
# moving the processed data into the dataframe
# ALL NEGATIVE TOKENS AND THEIR EVIDENCE WILL BE ADDED TO THE DATAFRAME; NOT JUST THE TOP 10 NEGATIVE TOKENS
# final_tokens = list(pd.unique(token_df['token']))
# list of painpoint_object objects
# all_objects = []

# for token in final_tokens:
#    review_id_evidence = {}
    
#    review_ids = token_df[token_df['token'] == token]['review_id']
#    for review_id in review_ids:

#        evidence = list(token_df[(token_df['review_id'] == review_id) & (token_df['token'] == token)]['neg_sentence'])
#        review_id_evidence[review_id] = [evidence]
    
    # creates a painpoint_object object
#    pain_point = painpoint_object(token, "Description", "Solution", "Yelp", "SimpangAsia", review_id_evidence, datetime.datetime(2018,12,1,0,0).timestamp())
#    all_objects.append(pain_point)
    
# adding to the db and checking if successful
#store_success = store_painpoint_insights(mongo_client, all_objects)
#if store_success:
#    print("yay its done")
#else:
#    print("riperdoodles")
